# %%
import pandas as pd

df = pd.read_csv("C:/Users/pc/Desktop/Programacion/Ticmas/Python/Ejercicios finales/population_by_country_2020.csv", sep = ",")

# %%
#Primeros 5 registros
df.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                   China         1438207241        0.39 %     5540090
# 1                   India         1377233523        0.99 %    13586631
# 2           United States          330610570        0.59 %     1937734
# 3               Indonesia          272931713        1.07 %     2898047
# 4                Pakistan          219992900        2.00 %     4327022
#
#    Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 0              153          9388211       -348399.0        1.7       38
# 1              464          2973190       -532687.0        2.2       28
# 2               36          9147420        954806.0        1.8       38
# 3              151          1811570        -98955.0        2.3       30
# 4              287           770880       -233379.0        3.6       23
#
#   Urban Pop % World Share
# 0        61 %     18.47 %
# 1        35 %     17.70 %
# ...

# %%
#Ultimos 5 registros
df.tail()
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 230              Montserrat               4991        0.06 %           3
# 231        Falkland Islands               3458        3.05 %         103
# 232                    Niue               1624        0.68 %          11
# 233                 Tokelau               1354        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 230               50              100             NaN       N.A.     N.A.
# 231                0            12170             NaN       N.A.     N.A.
# 232                6              260             NaN       N.A.     N.A.
# 233              136               10             NaN       N.A.     N.A.
# 234             2003                0             NaN       N.A.     N.A.
#
#     Urban Pop % World Share
# 230        10 %      0.00 %
# ...

# %%
#Dimensiones
print(df.shape)
# Out:
# (235, 11)

# %%
#Totalidad de registros
df.count()
# Out:
# Country (or dependency)    235
# Population (2020)          235
# Yearly Change              235
# Net Change                 235
# Density (P/Km²)            235
# Land Area (Km²)            235
# Migrants (net)             201
# Fert. Rate                 235
# Med. Age                   235
# Urban Pop %                235
# World Share                235
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country (or dependency)  235 non-null    object
#  1   Population (2020)        235 non-null    int64
#  2   Yearly Change            235 non-null    object
#  3   Net Change               235 non-null    int64
#  4   Density (P/Km²)          235 non-null    int64
#  5   Land Area (Km²)          235 non-null    int64
#  6   Migrants (net)           201 non-null    float64
#  7   Fert. Rate               235 non-null    object
#  8   Med. Age                 235 non-null    object
#  9   Urban Pop %              235 non-null    object
#  10  World Share              235 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.3+ KB

# %%
df.dtypes
# Out:
# Country (or dependency)     object
# Population (2020)            int64
# Yearly Change               object
# Net Change                   int64
# Density (P/Km²)              int64
# Land Area (Km²)              int64
# Migrants (net)             float64
# Fert. Rate                  object
# Med. Age                    object
# Urban Pop %                 object
# World Share                 object
# dtype: object

# %%
#Verificar la estructura
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Listar los nombres de las columnas
print(df.columns)
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km²)', 'Land Area (Km²)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
#Poblacion mayor a 100.000.000 habitantes
df[df['Population (2020)']>100000000]
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                    China         1438207241        0.39 %     5540090
# 1                    India         1377233523        0.99 %    13586631
# 2            United States          330610570        0.59 %     1937734
# 3                Indonesia          272931713        1.07 %     2898047
# 4                 Pakistan          219992900        2.00 %     4327022
# 5                   Brazil          212253150        0.72 %     1509890
# 6                  Nigeria          205052107        2.58 %     5175990
# 7               Bangladesh          164354176        1.01 %     1643222
# 8                   Russia          145922010        0.04 %       62206
# 9                   Mexico          128655589        1.06 %     1357224
# 10                   Japan          126552765       -0.30 %     -383840
# 11                Ethiopia          114357494        2.57 %     2884858
# ...

# %%
#Los 10 paises con mayor área en Km² 
df.nlargest(10, 'Land Area (Km²)')
# Out:
#    Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 8                   Russia          145922010        0.04 %       62206
# 0                    China         1438207241        0.39 %     5540090
# 2            United States          330610570        0.59 %     1937734
# 38                  Canada           37674770        0.89 %      331107
# 5                   Brazil          212253150        0.72 %     1509890
# 54               Australia           25439164        1.18 %      296686
# 1                    India         1377233523        0.99 %    13586631
# 31               Argentina           45111229        0.93 %      415097
# 63              Kazakhstan           18730568        1.21 %      225280
# 32                 Algeria           43685618        1.85 %      797990
#
#     Density (P/Km²)  Land Area (Km²)  Migrants (net) Fert. Rate Med. Age  \
# 8                 9         16376870        182456.0        1.8       40
# ...
